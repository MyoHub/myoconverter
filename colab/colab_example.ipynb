# %% [markdown]
# Connect to google drive.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Declare your git token. Refer to here on how to get it: https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-personal-access-token-classic.

# %%
git_token = 'paste_your_git_token'

# %% [markdown]
# Clone MyoConverter from Git.

# %%
! git clone https://{git_token}@github.com/MyoHub/myoconverter.git
# Out:
# Cloning into 'myoconverter'...
# remote: Enumerating objects: 4316, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 4316 (delta 71), reused 112 (delta 66), pack-reused 4187
# Receiving objects: 100% (4316/4316), 78.75 MiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (2741/2741), done.
# Updating files: 100% (2200/2200), done.

# %% [markdown]
# Install conda ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %% [markdown]
# Install mamba for faster build.

# %%
! conda install -y mamba
! mamba update -qy --all
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.2
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hbcca054_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     openssl-3.1.2              |       hd590300_0         2.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# ...

# %% [markdown]
# Install requirements. This may take a 5 - 10 minutes...

# %%
# %cd myoconverter
# Out:
# /content/myoconverter

# %% [markdown]
# Mamba install the required packages.

# %%
! mamba env update -n base -f conda_env.yml
# Out:
# anaconda/linux-64                                           Using cache
# anaconda/noarch                                             Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# opensim-org/linux-64  ⣾
# opensim-org/noarch    ⣾
# pkgs/main/linux-64    ⣾
# pkgs/main/noarch      ⣾
# pkgs/r/linux-64       ⣾  pkgs/main/noarch                                              No change
# [+] 0.1s
# opensim-org/linux-64  ⣾
# opensim-org/noarch    ⣾
# pkgs/main/linux-64    ⣾
# pkgs/r/linux-64       ⣾
# pkgs/r/noarch         ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
# [+] 0.2s
# opensim-org/linux-64  ⣾
# ...

# %% [markdown]
# Activate environment

# %%
# %%bash
#
# source activate myoconverter
# Out:
# bash: line 2: activate: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-0a6b0b7bf885> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nsource activate myoconverter\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %% [markdown]
# Change python path to the myoconverter folder

# %%
# %%bash
#
# env PYTHONPATH=/content/myoconverter
# Out:
# SHELL=/bin/bash
# NV_LIBCUBLAS_VERSION=11.11.3.6-1
# NVIDIA_VISIBLE_DEVICES=all
# COLAB_JUPYTER_TRANSPORT=ipc
# NV_NVML_DEV_VERSION=11.8.86-1
# NV_CUDNN_PACKAGE_NAME=libcudnn8
# CGROUP_MEMORY_EVENTS=/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events
# NV_LIBNCCL_DEV_PACKAGE=libnccl-dev=2.15.5-1+cuda11.8
# NV_LIBNCCL_DEV_PACKAGE_VERSION=2.15.5-1
# VM_GCE_METADATA_HOST=169.254.169.253
# HOSTNAME=2c7fc507a989
# LANGUAGE=en_US
# TBE_RUNTIME_ADDR=172.28.0.1:8011
# GCE_METADATA_TIMEOUT=3
# ...

# %% [markdown]
# Run conversion example.

# %%
# %%bash
#
# python examples/arm26.py
# Out:
# Traceback (most recent call last):
#   File "/content/myoconverter/examples/arm26.py", line 11, in <module>
#     from myoconverter.O2MPipeline import O2MPipeline
# ModuleNotFoundError: No module named 'myoconverter'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-19-55fb092c8813> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '\npython examples/arm26.py\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
# ...
